# %% [markdown]
# # PYTHON PROBLEM
#
# ## Importing Libraries

# %%
import jsonlines
import datetime
import json
import requests
import numpy as np
import os
import pandas as pd
from requests_oauthlib import OAuth1

# %% [markdown]
# # PART - A
#
#
# ## Setting up Twitter API

# %%
# obtained from twitter developers page.
api_creds = {
    'consumer_key':'pDzrvkuuvdY4VbiY0Ki5ZKc2R',
    'consumer_secret':'KfNabg5jaISzZbkjZ1aYgFw7LFE8Js1wsLAa9hVH8Uund11uIH',
    'access_token':'144574952-sbza1XsfCjEFKmyQNLTgvm7tNNcB80drgM3dalGP',
    'access_token_secret':'OJXMcdHoBjvIypTukF0E86n2EHvoPJhc7sX6Pc8nd0ExM'
}

# creating authentication session to use twitter api
auth = OAuth1(api_creds['consumer_key'], api_creds['consumer_secret'],
                     api_creds['access_token'],api_creds['access_token_secret'])

# %% [markdown]
# ## Fetching tweets

# %%
def getUserTweets(screen_name,authorization,fetchAttempts):
    # the url to fetch user_timeline tweets (available on twitter developers webpage)
    api_url='https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name={}&count=200&trim_user=true&tweet_mode=extended'
    api_url=api_url.format(screen_name)
    tweets = []
    for i in range(fetchAttempts):
        tweets = tweets + requests.get(api_url,auth=authorization).json()
    return tweets

# %%
handle_name = 'midasiiitd'
tweets = getUserTweets(handle_name,auth,1)

# %% [markdown]
# ## Dumping all tweets into JSONlines file

# %%
def saveJsonline(tweetList,filename):
    with open(filename,'w',encoding="utf-8") as file:
        book = jsonlines.Writer(file)
        book.write_all(tweetList)
        book.close
        
# calling the function to save tweets to jsonl file named 'tweets.jsonl'
saveJsonline(tweets,'tweets.jsonl')

# %% [markdown]
# # PART - B
#
# ## Parsing JSONlines file to load tweets

# %%
loadedTweets = []
with jsonlines.open('tweets.jsonl') as reader:
    for tweet in reader:
        loadedTweets.append(tweet)

# %%
# displaying length of loadedTweets
print(len(loadedTweets))

# displaying a single tweet from loadedTweets
loadedTweets[0]
# Out:
# 200
# {'created_at': 'Mon Apr 08 19:38:09 +0000 2019',
#  'id': 1115338057400573953,
#  'id_str': '1115338057400573953',
#  'full_text': 'RT @multimediaeval: Announcing the 2019 MediaEval multimedia tasks: https://t.co/V6NMt1vaNV Participation is open for anyone who is interes…',
#  'truncated': False,
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'multimediaeval',
#     'name': 'MultimediaEval',
#     'id': 704779989884014593,
#     'id_str': '704779989884014593',
#     'indices': [3, 18]}],
#   'urls': [{'url': 'https://t.co/V6NMt1vaNV',
#     'expanded_url': 'http://multimediaeval.org/mediaeval2019',
#     'display_url': 'multimediaeval.org/mediaeval2019',
#     'indices': [68, 91]}]},
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1021355762575073281, 'id_str': '1021355762575073281'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Mon Mar 18 06:40:38 +0000 2019',
#   'id': 1107532242232979456,
#   'id_str': '1107532242232979456',
#   'full_text': 'Announcing the 2019 MediaEval multimedia tasks: https://t.co/V6NMt1vaNV Participation is open for anyone who is interested. Registration starts soon. @sigmm @ACMMM19',
#   'truncated': False,
#   'display_text_range': [0, 165],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'sigmm',
#      'name': 'ACM SIGMM',
#      'id': 191650709,
#      'id_str': '191650709',
#      'indices': [150, 156]},
#     {'screen_name': 'ACMMM19',
#      'name': 'ACMMM19',
#      'id': 961976587246817280,
#      'id_str': '961976587246817280',
#      'indices': [157, 165]}],
#    'urls': [{'url': 'https://t.co/V6NMt1vaNV',
#      'expanded_url': 'http://multimediaeval.org/mediaeval2019',
#      'display_url': 'multimediaeval.org/mediaeval2019',
#      'indices': [48, 71]}]},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 704779989884014593, 'id_str': '704779989884014593'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 15,
#   'favorite_count': 20,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 15,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %% [markdown]
# ## Formatting each tweet to show following details
# ● The text of the tweet.
#
# ● Date and time of the tweet.
#
# ● The number of favorites/likes.
#
# ● The number of retweets.
#
# ● Number of Images present in Tweet. If no image returns None.

# %%
# this function parse individual tweet into required format.
def tweetInfo(tweet):
    cleanTweet = []
    for col in ['created_at','full_text', 'favorite_count','retweet_count']:
        cleanTweet.append(tweet[col])
    
    # Converting string date to datetime format.
    cleanTweet[0] = datetime.datetime.strptime(cleanTweet[0][:-10]+cleanTweet[0][-4:],"%a %b %d %H:%M:%S %Y")
    
    # this piece of code is for finding number of images in the tweet if exists.
    count=0
    if 'extended_entities' in tweet.keys():
        if 'media' in tweet['extended_entities'].keys():
            for m in tweet['extended_entities']['media']:
                if m['type'] == 'photo':
                    count = count + 1
    
    if(count == 0):
        cleanTweet.append(None)
    else:
        cleanTweet.append(count)
    
    return cleanTweet

# %% [markdown]
# ## Displaying the tweets table

# %%
def TweetsTable(tweets):
    table = [tweetInfo(t) for t in tweets]  
    df = pd.DataFrame(table,columns=['Timestamp','Tweets','Likes','Retweets','Image Count'])
    pd.options.display.max_rows
    pd.set_option('display.max_colwidth', -1)
    return df

table = TweetsTable(loadedTweets)
table.to_csv("tweets.csv", index=False)
display(table)
# Out:
#               Timestamp  \
# 0   2019-04-08 19:38:09
# 1   2019-04-08 07:08:12
# 2   2019-04-08 03:27:42
# 3   2019-04-07 14:17:29
# 4   2019-04-07 14:17:09
# 5   2019-04-07 11:43:24
# 6   2019-04-07 06:55:19
# 7   2019-04-07 06:53:38
# 8   2019-04-07 05:32:27
# 9   2019-04-07 05:29:40
# 10  2019-04-06 17:11:29
# 11  2019-04-06 16:43:27
# 12  2019-04-05 16:08:37
# 13  2019-04-05 04:05:11
# 14  2019-04-05 04:04:43
# 15  2019-04-03 18:31:53
# 16  2019-04-03 17:04:32
# 17  2019-04-03 09:03:40
# 18  2019-04-03 07:46:02
# 19  2019-04-02 04:20:13
# 20  2019-04-02 02:44:54
# 21  2019-04-02 02:35:44
# 22  2019-04-01 06:53:08
# 23  2019-03-31 10:21:24
# 24  2019-03-29 19:43:24
# 25  2019-03-29 17:16:40
# 26  2019-03-29 17:04:30
# 27  2019-03-29 17:03:29
# 28  2019-03-29 17:02:24
# 29  2019-03-29 05:35:22
# ..                  ...
# 170 2019-01-06 04:09:54
# 171 2019-01-06 04:07:29
# 172 2019-01-06 04:05:38
# 173 2019-01-03 06:14:05
# 174 2019-01-01 17:21:49
# 175 2019-01-01 17:17:56
# 176 2019-01-01 16:14:24
# 177 2018-12-27 10:28:31
# 178 2018-12-27 09:59:06
# 179 2018-12-27 02:33:58
# 180 2018-12-26 09:41:04
# 181 2018-12-25 04:15:15
# 182 2018-12-25 03:00:21
# 183 2018-12-24 07:39:21
# 184 2018-12-21 03:50:39
# 185 2018-12-20 18:05:35
# 186 2018-12-20 06:14:52
# 187 2018-12-19 02:16:31
# 188 2018-12-18 14:42:27
# 189 2018-12-18 14:27:12
# 190 2018-12-18 14:15:32
# 191 2018-12-18 12:34:10
# 192 2018-12-18 12:33:42
# 193 2018-12-18 04:38:35
# 194 2018-12-17 16:57:00
# 195 2018-12-17 15:05:44
# 196 2018-12-17 14:37:00
# 197 2018-12-17 14:05:47
# 198 2018-12-16 15:01:20
# 199 2018-12-12 03:56:19
#
#                                                                                                                                                                                                                                                                                                                                        Tweets  \
# 0    RT @multimediaeval: Announcing the 2019 MediaEval multimedia tasks: https://t.co/V6NMt1vaNV Participation is open for anyone who is interes…
# 1    Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internship in the BRAIN lab at Singapore University of Technology &amp; Design @sutdsg, Singapore.\nWe wish her the best luck for the internship.\n\n#MIDAS #StudentAchievement https://t.co/snX2GkzvQg
# 2    @midasIIITD thanks all students who have appeared for the interview yesterday. We will announce the interview results for MIDAS internship latest by 14th April 2019. Sorry for the delay since we are carefully evaluating all applications that we have received for the internship. https://t.co/FANz5vImwU
# 3    @himanchalchandr Meanwhile, complete CV/NLP task first.
# 4    @sayangdipto123 Submit as per the guideline again.
# 5    We request all students whose interview are scheduled today to join at the time given to them and not before or after. We have other interviews scheduled which will be affected. \nThanks much.
# 6    Other queries: "none of the Tweeter Apis give the correct count of favorites tested for most of them, all give the wrong count. same is true for retweet. this mostly happens if the no. of likes, retweet is very large. So, what shld be done?"\nAns: Just use the count given by API.
# 7    Other queries: "do we have to make two different repositories on Github as "Python Problem" and "CV Problem". Or we have to make a single repository named "root" and upload our code in that?"\nAnd: Have one repository of any name which has two folders. One python and other cv/nlp
# 8    Other queries: "If using Twitter api, it does not include any information about images in the response objects sent, so how do we retrieve the image info as requested?"\nAns: U have to use twitter api or wrappers based on it like tweepy.\nTwitter API does provide image information.
# 9    Response to some queries asked by students on @midasIIITD task.\nWhat does the line "dump the responses into JSONlines file" mean?\nIt means you have to dump the response into a jsonlines file. jsonlines is a file extension more popularly know as .jsonl\n#MIDAS #Research #Internship
# 10   RT @kdnuggets: Top 8 #Free Must-Read #Books on #DeepLearning #KDN https://t.co/1DtlN91Yjj
# 11   @nupur_baghel @PennDATS Congratulation @nupur_baghel on getting admit from @PennDATS. \nShe got 5/10 acceptance. She has worked at @midasIIITD on the #kikichallenge problem. We are glad to know that it inspired her to pursue further research. We wish her a great success ahead. \n#MSc #DataScience #UPenn https://t.co/2daLOHGPBU
# 12   We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal. Kindly check your spam folder if you have not received the email. We will evaluate all solutions received until April 10 midnight and announce results by April 14.
# 13   RT @rfpvjr: Our NAACL paper on polarization in language on Twitter surrounding mass shootings is up on arXiv! https://t.co/g7wiegXxDg\nThis…
# 14   RT @kdnuggets: Effective Transfer Learning For NLP https://t.co/Z1m0AzlfVv https://t.co/ccX4Uhxjn8
# 15   RT @stanfordnlp: What’s new in @Stanford CS224N Natural Language Processing with Deep Learning for 2019? Question answering—1D CNNs—subword…
# 16   RT @DeepMindAI: Today we're releasing a large-scale extendable dataset of mathematical questions, for training (and evaluating the abilitie…
# 17   RT @ylecun: Congratulations Jitendra Malik !\n\nAwards are raining on FAIRies these days... https://t.co/1WNcSeQLZe
# 18   RT @IIITDelhi: Another chance to take admission in the Ph.D. program in IIIT Delhi. \nAdmissions open for Ph.D. program mathematics \n\nLog on…
# 19   Dear @midasIIITD internship candidates who have submitted their solutions to the task, we have sent you an email regarding your results. \n\nStudents who have applied through @IIITDelhi, you will soon be contacted on the internship task. \n\n#MIDAS #Summer #Research #Internship
# 20   Looking forward to your paper submission to @IEEEBigMM19. \n\nImportant Dates:\nRegular Paper: 11:59pm PST, May 10, 2019     \nShort Paper: 11:59pm PST, May 10, 2019   \nIndustry Paper: 11:59pm PST, May 10, 2019  \nDemonstration Paper: 11:59pm PST, May 10, 2019\n\nContact TPC @RatnRajiv
# 21   RT @ngrams: Reproducibility in multimedia research in @sigmm records https://t.co/hOyMxtmy7A Plus reminder to past-year authors: Today 1 Ap…
# 22   Online application for https://t.co/DJFDrQsHZP. Admission 2019 at @IIITDelhi has been open\n\nLog on to know more and apply: https://t.co/w7d2UMTVh7\n\nLast Date: 18th April 2019\n\n#MTech #IIITD #Admission
# 23   RT @ACMMM19: A final reminder of the Reproducibility Track: Authors of 2017 and 2018 papers are invited to submit a short reproducibility p…
# 24   RT @isarth23: Thanks for the support and help @debanjanbhucs @RatnRajiv and @midasIIITD. It was a great learning experience! Glad to be par…
# 25   Since SemEval-2019 will be held June 6-7, 2019 in Minneapolis, USA, collocated with NAACL-HLT 2019, it will great students for @midasIIITD students to attend the conference and learn from worldclass researchers. +@aggarwal_kartik
# 26   +@aggarwal_kartik.\nCongrats! Wish you many more success.
# 27   RT @aggarwal_kartik: Our work (@midasIIITD ) accepted at SemEval 2019 at @NAACLHLT : "MIDAS at SemEval-2019 Task 9: Suggestion Mining from…
# 28   Congratulations! @midasIIITD team, @isarth23 @LaibaMehnaz @Simcyy @debanjanbhucs @RatnRajiv @the_dhumketu for getting two papers accepted at SemEval 2019. \nMany thanks to our collaborators Haimin and Karan for their help.\n\n#NLP #Research #SocialMedia #Analytics #DeepLearning
# 29   @EEMLcommunity @radamihalcea too many deadlines coming, @ACMMM19 @IEEEBigMM19 @EEMLcommunity
# ..                                                                                            ...
# 170  Since 1993, ACM Multimedia has been bringing together researchers and practitioners from academia and industry to present innovative research results and discuss recent advancements. \n\nCheck @ACMMM19 website for more details: \nhttps://t.co/QroXuO8ZAV\n\n#ACMMM #Multimedia #Research
# 171  @ACMMM19 is structured around four themes (alphabetical):\n\nEngaging users with multimedia\nMultimedia experience\nMultimedia systems\nUnderstanding multimedia content\n\nMultimedia research focuses on integration of the multiple perspectives offered by different digital modalities.
# 172  ACM Multimedia 2019: First Call for Papers/Call for Contributions\n@ACMMM19 is the premier international conference in the area of multimedia within the field of computer science.  \nDetails on the conference themes are available on the conference website: \nhttps://t.co/QroXuO8ZAV
# 173  RT @ACMMM19: Happy new year! 2019 started with a bang. Thanks to everyone working to help resolve the ACM webserver hack issues. Please wat…
# 174  You may follow @midasIIITD updates through following:\n\nWebsite: https://t.co/sPvbKhflKQ\nFacebook: https://t.co/yMDAL2pof0\nLinkedIn: https://t.co/ZPNNnLTi8Z\n\nWe look forward to producing some groundbreaking work in 2019 which can help society through ML and Multimedia Processing.
# 175  Today, @midasIIITD completed one year at @IIITDelhi. In last one year, we have shown our strong presence in research communities of top-tier conferences and journals through our world-class research. This could not have been possible without the hard work of MIDAS researchers. https://t.co/zCdQr8Zfwe
# 176  RT @debanjanbhucs: Happy anniversary to @midasIIITD . It surely has been a productive year for us and hope to see some ground breaking work…
# 177  Two Research Assistant (RA) positions are still open. Contact us if you are eligible and interested to work on the mentioned projects. \n\nPS: RAs are full-time jobs. Only apply if you have finished your studies.
# 178  Positions for two Research Assistants (RA) are still open at @midasIIITD. Interested candidates may send their CV at midas AT https://t.co/ey7h1zgmKD\nPS: RAs are full-time positions. Thus, only candidates who have finished their study are requested to apply. \n#MIDAS #Humonics #RA
# 179  RT @TCoolsIT: I wrote a blogpost on CoreNLP highlighting some of its functionality. If you want a quick dip before diving into the course,…
# 180  @RatnRajiv delivered a research talk at the Central Research Laboratories of NEC Corporation, Japan. He discussed several multimedia systems for society and healthcare. He had interesting pre and post-talk discussions on multimedia systems for cybersecurity that can help society. https://t.co/itWHzv0ias
# 181  @midasIIITD look forward to work together. https://t.co/nrpf32ODo2
# 182  @the_dhumketu @punnibhai @Hitkul_, FYI. https://t.co/yZb9mdr6IB
# 183  RT @iiit_hyderabad: KCIS Distinguished Lecture by Andrew Zisserman on Learning from Sight and Sound. Three-time Marr Prize winner Zisserman…
# 184  RT @StanfordAILab: Our latest blog post is out! \n\nCheck it out for a recording and summary of highlights from the event "AI and the Future…
# 185  RT @medialab: In two new papers, @PratikShahPhD and collaborators present novel #AI and machine learning methods to improve diagnosis at th…
# 186  RT @RatnRajiv: Wonderful get together with our NII colleagues. Prior to that we had a wonderful talk with Prof Chua Tat-Seng from National…
# 187  @ACMMM19 is the premier international conference in the area of multimedia within the field of computer science. Multimedia research focuses on integration of the multiple perspectives offered by different digital modalities including images, text, video, music, and sensor data. https://t.co/8RPzQHnB34
# 188  Feel free to contact us if you have any query on @ACMMM19. We look forward to your submissions to ACM Multimedia conference 2019. \n\nCheck more details on submission at https://t.co/xA2jk0KPPC\n\n#Multimedia #Research #ACMMM2019 #Nice
# 189  @NilayShri @RatnRajiv @ACMMM19 Looking forward to your paper to @ACMMM19.
# 190  @midasIIITD head, Dr. @RatnRajiv appointed as one of the publicity co-chairs for @ACMMM19. ACM Multimedia is the premier conference for Multimedia research. We look forward to supporting a large number of submissions to https://t.co/QroXuO8ZAV this year from India. \n\n#Multimedia
# 191  @ACMMM19 @the_dhumketu fill the volunteer form for reviewer.
# 192  RT @ACMMM19: New in 2019! Volunteer to serve as ACM Multimedia Area Chair or Reviewer. Please provide information on your qualifications in…
# 193  RT @IIITDelhi: Congratulations! authors Yaman @the_dhumketu, @RatnRajiv, and team @midasIIITD for winning the best poster runner-up at 20th…
# 194  Best wishes to @midasIIITD students @_himanshu0113, @Hitkul_, and Shivangi on starting their research internship at National Institute of Informatics (NII), Tokyo, Japan. They will be working with our collaborators Prof Yu and Prof Satoh for six months. \n\n#internship #tokyo #nii https://t.co/JwWA8D9uHH
# 195  RT @MIT: Computer model could improve human-machine interaction, provide insight into how children learn language. https://t.co/ToQo6GTMcG…
# 196  RT @kdnuggets: Great @Wired interview with Geoff #Hinton on #AI risks, explanation, Graphcore chips, brain vs neural nets, and why there wi…
# 197  RT @harvardmed: A defective metabolic pathway in aging immune cells may explain why the elderly commonly experience weakened immunity https…
# 198  RT @stanfordnlp: Thread on (neural) reasoning. 👇 https://t.co/kyJs5xztwA
# 199  Congratulations! Yaman @the_dhumketu, Rohit, Salik, Yifang, Roger, @RatnRajiv for winning the best poster runner-up in 20th IEEE International Symposium on Multimedia (ISM) conference in Taichung, Taiwan.\n\nGreat work team @midasIIITD MIDAS and @IIITDelhi. \n\n#multimedia #ieee #ism https://t.co/zZk21IBAS1
#
#      Likes  Retweets  Image Count
# 0    0      15       NaN
# 1    13     2         1.0
# 2    4      0         1.0
# 3    0      0        NaN
# 4    0      0        NaN
# 5    1      1        NaN
# 6    5      2        NaN
# 7    4      1        NaN
# 8    6      1        NaN
# 9    7      1        NaN
# 10   0      2        NaN
# 11   18     3         1.0
# 12   11     1        NaN
# 13   0      16       NaN
# 14   0      11        1.0
# 15   0      59       NaN
# 16   0      870      NaN
# 17   0      16       NaN
# 18   0      4        NaN
# 19   8      1        NaN
# 20   5      1        NaN
# 21   0      7        NaN
# 22   7      2        NaN
# 23   0      10       NaN
# 24   0      2        NaN
# 25   9      1        NaN
# 26   2      0        NaN
# 27   0      1        NaN
# 28   9      1        NaN
# 29   0      0        NaN
# ..  ..     ..         ..
# 170  5      1        NaN
# 171  1      0        NaN
# 172  4      2        NaN
# 173  0      2        NaN
# 174  4      2        NaN
# 175  14     5         1.0
# 176  0      4        NaN
# 177  2      1        NaN
# 178  5      3        NaN
# 179  0      12       NaN
# 180  14     2         1.0
# 181  1      0        NaN
# 182  2      1        NaN
# 183  0      11       NaN
# 184  0      32       NaN
# 185  0      8        NaN
# 186  0      3        NaN
# 187  2      3         1.0
# 188  3      2        NaN
# 189  3      0        NaN
# 190  12     5        NaN
# 191  1      0        NaN
# 192  0      7        NaN
# 193  0      3        NaN
# 194  14     4         2.0
# 195  0      20       NaN
# 196  0      20       NaN
# 197  0      167      NaN
# 198  0      10       NaN
# 199  16     3         1.0
#
# [200 rows x 5 columns]
